# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE

# %%
data = pd.read_csv("glass.csv")
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
data_copy = data.drop_duplicates()
data_copy
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [213 rows x 10 columns]

# %%
x = data.drop("Type", axis=1)  # Drop the "left" column from data (axis=1 means column-wise)
y = data["Type"]  # Extract the "left" column as the target variable

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
smt = SMOTE()
x_train_smt, y_train_smt = smt.fit_resample(x_train, y_train)

# %%
model = DecisionTreeClassifier()
model.fit(x_train_smt, y_train_smt)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_train_smt,y_train_smt)
model.score(x_test,y_test)
# Out:
# 0.6615384615384615

# %%
model.score(x_train_smt,y_train_smt)
# Out:
# 1.0

# %%
model.get_depth()
# Out:
# 11

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 7, 3, 7, 2, 2, 1, 1, 2, 2, 6, 2, 1, 2, 6, 6, 7, 1, 1, 6, 3, 7,
#        7, 7, 3, 1, 1, 1, 2, 1, 5, 2, 3, 2, 1, 7, 5, 3, 1, 1, 5, 7, 3, 2,
#        3, 6, 5, 3, 5, 2, 1, 1, 1, 2, 1, 1, 1, 2, 5, 3, 2, 2, 2, 7, 2],
#       dtype=int64)

# %%
import pandas as pd
results_df = pd.DataFrame({"True Values": y_test, "Predicted Values": y_pred})
results_df
# Out:
#      True Values  Predicted Values
# 9              1                 1
# 197            7                 7
# 66             1                 3
# 191            7                 7
# 117            2                 2
# ..           ...               ...
# 5              1                 2
# 135            2                 2
# 56             1                 2
# 199            7                 7
# 173            5                 2
#
# [65 rows x 2 columns]

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[13,  2,  3,  1,  0,  0],
#        [ 5, 12,  2,  3,  1,  0],
#        [ 0,  0,  4,  0,  0,  0],
#        [ 0,  3,  0,  2,  1,  0],
#        [ 0,  0,  0,  0,  3,  0],
#        [ 1,  0,  0,  0,  0,  9]], dtype=int64)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
# Display the confusion matrix as a plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

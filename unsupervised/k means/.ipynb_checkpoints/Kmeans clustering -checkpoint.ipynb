# %%
import pandas as pd 
import numpy as np 
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('migration.csv')
data
# Out:
#                        Country Name     1962     1967     1972     1977  \
# 0                        Arab World  -485569  -849826  -876979  1697107
# 1            Caribbean small states  -247909  -316430  -289373  -284532
# 2    Central Europe and the Baltics   112936  -227571  -104933   -85960
# 3        Early-demographic dividend -1127882 -2453929 -3192784 -4981537
# 4               East Asia & Pacific  -479477   628975  -808879 -1454415
# ..                              ...      ...      ...      ...      ...
# 228                         Vietnam        0        0        0  -813123
# 229           Virgin Islands (U.S.)    10270     3245     9407     1961
# 230                     Yemen, Rep.  -100000  -245662  -353000   -75000
# 231                          Zambia     2500    -4245    26662    17573
# 232                        Zimbabwe   -10001   -27996   -30360  -101516
#
#         1982     1987     1992     1997      2002      2007      2012
# ...

# %%
data_numeric = data.drop(columns=['Country Name'])

# %%
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data_numeric)

# %%
data_numeric
# Out:
#         1962     1967     1972     1977     1982     1987     1992     1997  \
# 0    -485569  -849826  -876979  1697107   103693 -1021606   293332 -1432980
# 1    -247909  -316430  -289373  -284532  -303086  -387993  -249602  -181604
# 2     112936  -227571  -104933   -85960  -279101  -819390 -1514119 -1176975
# 3   -1127882 -2453929 -3192784 -4981537  1228808 -1903124 -8288636 -7729474
# 4    -479477   628975  -808879 -1454415   713290   392043 -2395809  -385097
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 228        0        0        0  -813123  -324942  -332327  -394236  -216001
# 229    10270     3245     9407     1961    -3492   -11156    -4618    -3936
# 230  -100000  -245662  -353000   -75000   -50000   -50000   672800  -100000
# 231     2500    -4245    26662    17573    58483     2822   -22952    79445
# 232   -10001   -27996   -30360  -101516   141524   120505  -191803  -200000
#
#          2002      2007      2012
# ...

# %%
# Apply K-Means
model = KMeans(n_clusters=3, random_state=42)  # Example with 3 clusters
clusters = model.fit_predict(data_normalized)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data['Cluster'] = clusters

# %%
from sklearn.decomposition import PCA
plt.scatter(data_pca[:, 0], data_pca[:, 1], c=clusters, cmap='viridis')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('K-Means Clustering of Migration Data')
plt.show()

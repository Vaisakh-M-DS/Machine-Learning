# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn. model_selection import train_test_split

# %%
data = pd.read_csv("CAR DETAILS.CSV")
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
car_name=data["name"].unique()
fuel_type=data["fuel"].unique()
seller_type=data["seller_type"].unique()
transmission_type=data["transmission"].unique()
owner_type=data["owner"].unique()

# %%
name = LabelEncoder()
data['name'] = name.fit_transform(data['name'])

fuel = LabelEncoder()
data['fuel'] = fuel.fit_transform(data['fuel'])

seller = LabelEncoder()
data['seller_type'] = seller.fit_transform(data['seller_type'])

transmission = LabelEncoder()
data['transmission'] = transmission.fit_transform(data['transmission'])

owner = LabelEncoder()
data['owner'] = owner.fit_transform(data['owner'])

# %%
data
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0      775  2007          60000      70000     4            1             1
# 1     1041  2007         135000      50000     4            1             1
# 2      505  2012         600000     100000     1            1             1
# 3      118  2017         250000      46000     4            1             1
# 4      279  2014         450000     141000     1            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 4335   602  2014         409999      80000     1            1             1
# 4336   601  2014         409999      80000     1            1             1
# 4337   777  2009         110000      83000     4            1             1
# 4338   381  2016         865000      90000     1            1             1
# 4339  1154  2016         225000      40000     4            1             1
#
#       owner
# 0         0
# 1         0
# 2         0
# ...

# %%
x = data.drop('selling_price',axis = 1)
y = data['selling_price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25,random_state=90)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.4418187611097706

# %%
model.score(x_train, y_train)
# Out:
# 0.4517859000120189

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 363436.9969566 ,  203251.06339547,  114686.59596246, ...,
#        1397793.58673798,  243191.20905818,  571866.53285874])

# %%
pd.DataFrame({'True Value':y_test, 'Predicted Value': y_pred})
# Out:
#       True Value  Predicted Value
# 2095      263000     3.634370e+05
# 1504      180000     2.032511e+05
# 3884      160000     1.146866e+05
# 502       300000     2.716335e+05
# 1113      250000     3.891400e+05
# ...          ...              ...
# 4176      225000     5.161875e+05
# 1371      475000     6.800588e+05
# 1842      520000     1.397794e+06
# 1221      165000     2.431912e+05
# 773       250000     5.718665e+05
#
# [1085 rows x 2 columns]

# %%
plt.scatter(y_test,y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
# Out:
# Text(0, 0.5, 'Predicted Salary')
